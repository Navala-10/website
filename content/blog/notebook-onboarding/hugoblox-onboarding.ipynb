# %%
from IPython.display import HTML
HTML("""<script>
  document.documentElement.setAttribute('data-theme', 'synthwave');
  document.documentElement.classList.add('dark');
</script>""")
# Out:
# <script>
#   // Force le thème Synthwave de DaisyUI au chargement
#   document.documentElement.setAttribute('data-theme', 'synthwave');
#   document.documentElement.classList.add('dark');
# </script>

# %%
from IPython.display import HTML
HTML("""<div style='font-family:Inter,ui-sans-serif; padding: 2rem; border-radius: 8px; background: rgba(0,0,0,0.2);'>
  <h1 style='font-size: 2.5rem; font-weight: bold; margin-bottom: 0.5rem;'>Nawal Ibnousaih</h1>
  <p style='font-size: 1.25rem; color: #f43f5e; font-weight: 600; margin-bottom: 1.5rem;'>Aspiring Ph.D. Researcher | Psycholinguistics & Neuroscience</p>
  <p style='font-size: 1.1rem; line-height: 1.6; max-width: 800px;'>
    With a Master’s degree specializing in <strong>English Studies, Neurodevelopmental Disorders, and Linguistics</strong>, 
    my academic journey is driven by a fascination with how the brain processes language. Blending linguistic theory 
    with a deep understanding of cognitive differences, I am currently seeking <strong>Ph.D. opportunities for next year</strong> 
    in the fields of <strong>psycholinguistics and neuroscience</strong>.
  </p>
</div>""")
# Out:
# <div style='font-family:Inter,ui-sans-serif; padding: 2rem; border-radius: 8px; background: rgba(0,0,0,0.2);'>
#   <h1 style='font-size: 2.5rem; font-weight: bold; margin-bottom: 0.5rem;'>Nawal Ibnousaih</h1>
#   <p style='font-size: 1.25rem; color: #f43f5e; font-weight: 600; margin-bottom: 1.5rem;'>Aspiring Ph.D. Researcher | Psycholinguistics & Neuroscience</p>
#   <p style='font-size: 1.1rem; line-height: 1.6; max-width: 800px;'>
#     With a Master’s degree specializing in <strong>English Studies, Neurodevelopmental Disorders, and Linguistics</strong>,
#     my academic journey is driven by a fascination with how the brain processes language. Blending linguistic theory
#     with a deep understanding of cognitive differences, I am currently seeking <strong>Ph.D. opportunities for next year</strong>
#     in the fields of <strong>psycholinguistics and neuroscience</strong>.
#   </p>
# </div>

# %% [markdown]
# > Open to research collaborations and Ph.D. opportunities. Feel free to reach out!
